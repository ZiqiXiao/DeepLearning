# %%
import cv2 # opencv读取的格式是BGR，与matplotlib不同
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

pic_path = '/Users/xiaoziqi/Desktop/Code/deep-learning/OpenCV/data/cat1.jpeg'

# %%
pic_path = '/Users/xiaoziqi/Desktop/Code/deep-learning/OpenCV/data/cat1.jpeg'
img = cv2.imread(pic_path)

# %%
img
# Out:
# array([[[ 38,  36,  42],
#         [ 38,  36,  42],
#         [ 37,  35,  41],
#         ...,
#         [ 61,  78,  99],
#         [ 60,  76,  99],
#         [ 61,  77, 100]],
#
#        [[ 38,  36,  42],
#         [ 38,  36,  42],
#         [ 38,  36,  42],
#         ...,
#         [ 62,  79, 100],
#         [ 62,  78, 101],
#         [ 63,  79, 102]],
#
#        [[ 39,  37,  43],
#         [ 39,  37,  43],
#         [ 39,  37,  43],
#         ...,
#         [ 61,  78,  99],
#         [ 60,  77,  98],
#         [ 61,  78,  99]],
#
#        ...,
#
#        [[ 42,  40,  46],
#         [ 42,  40,  46],
#         [ 42,  38,  44],
#         ...,
#         [ 92,  98, 111],
#         [ 90,  96, 109],
#         [ 85,  93, 106]],
#
#        [[ 43,  41,  47],
#         [ 44,  42,  48],
#         [ 42,  38,  44],
#         ...,
#         [111, 119, 132],
#         [100, 108, 121],
#         [ 78,  86,  99]],
#
#        [[ 45,  41,  47],
#         [ 47,  43,  49],
#         [ 45,  38,  45],
#         ...,
#         [116, 124, 137],
#         [112, 119, 134],
#         [ 83,  92, 106]]], dtype=uint8)

# %%
# 图像的显示，也可以创建多个窗口
cv2.imshow('image', img)
# 等待时间，毫秒级，0表示任意键终止
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (301, 320, 3)

# %%
img_gray = cv2.imread(pic_path, cv2.IMREAD_GRAYSCALE)
img_gray
# Out:
# array([[ 38,  38,  37, ...,  82,  81,  82],
#        [ 38,  38,  38, ...,  83,  83,  84],
#        [ 39,  39,  39, ...,  82,  81,  82],
#        ...,
#        [ 42,  42,  40, ..., 101,  99,  96],
#        [ 43,  44,  40, ..., 122, 111,  89],
#        [ 43,  45,  41, ..., 127, 123,  95]], dtype=uint8)

# %%
img_gray.shape
# Out:
# (301, 320)

# %%
# 图像的显示，也可以创建多个窗口
cv2.imshow('image', img_gray)
# 等待时间，毫秒级，0表示任意键终止
cv2.waitKey(500)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xx/r2gz1j4j16q0vg6lb_0f15th0000gn/T/ipykernel_91672/875077692.py in <module>
#       1 # 图像的显示，也可以创建多个窗口
# ----> 2 cv2.imshow('image', img_gray)
#       3 # 等待时间，毫秒级，0表示任意键终止
#       4 cv2.waitKey(500)
#       5 cv2.destroyAllWindows()
#
# NameError: name 'cv2' is not defined

# %%
cv2.imwrite('data/my_cat.jpeg', img_gray)

# %% [markdown]
# ### 数据读取-视频

# %% [markdown]
# - cv2.VideoCapture可以捕获摄像头，用数字来控制不同的设备，例如0，1.
# - 如果是视频文件，直接指定好路径即可。

# %%
vc = cv2.VideoCapture('data/test.mp4')

# %%
# 检查打开是否正确
if vc.isOpened():
    is_open, frame =  vc.read()
else:
    is_open = False
is_open
# Out:
# array([[[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        ...,
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]]], dtype=uint8)

# %%
while open:
    ret, frame = vc.read()
    if frame is None:
        break
    if ret:
        v_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        cv2.imshow('result', v_gray)
        if cv2.waitKey(10) & 0xFF == 27:
            break
vc.release()
cv2.destroyAllWindows()

# %%
vc = cv2.VideoCapture(0)
while(True):
    # 读取一帧，read()方法是其他两个类方法的结合，具体文档
    # ret为bool类型，指示是否成功读取这一帧
    ret, frame = vc.read()
    # 就是个处理一帧的例子，这里转为灰度图
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # 不断显示一帧，就成视频了
    # 这里没有提前创建窗口，所以默认创建的窗口不可调整大小
    # 可提前使用cv.WINDOW_NORMAL标签创建个窗口
    cv2.imshow('frame',gray)
    # 若没有按下q键，则每1毫秒显示一帧
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# 所有操作结束后不要忘记释放
vc.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### 截取部分图像数据

# %%
def cv_show(name_image, image):
    # 图像的显示，也可以创建多个窗口
    cv2.imshow(name_image, image)
    # 等待时间，毫秒级，0表示任意键终止
    cv2.waitKey(500)
    cv2.destroyAllWindows()

# %%
pic_path = '/Users/xiaoziqi/Desktop/Code/deep-learning/OpenCV/data/cat1.jpeg'
img = cv2.imread(pic_path)
cat = img[0:200, 0:200]
cv_show('cat', cat)

# %% [markdown]
# ### 颜色通道提取

# %%
img = cv2.imread(pic_path)
b, g, r = cv2.split(img)

# %%
b
# Out:
# array([[ 38,  38,  37, ...,  61,  60,  61],
#        [ 38,  38,  38, ...,  62,  62,  63],
#        [ 39,  39,  39, ...,  61,  60,  61],
#        ...,
#        [ 42,  42,  42, ...,  92,  90,  85],
#        [ 43,  44,  42, ..., 111, 100,  78],
#        [ 45,  47,  45, ..., 116, 112,  83]], dtype=uint8)

# %%
g
# Out:
# array([[ 36,  36,  35, ...,  78,  76,  77],
#        [ 36,  36,  36, ...,  79,  78,  79],
#        [ 37,  37,  37, ...,  78,  77,  78],
#        ...,
#        [ 40,  40,  38, ...,  98,  96,  93],
#        [ 41,  42,  38, ..., 119, 108,  86],
#        [ 41,  43,  38, ..., 124, 119,  92]], dtype=uint8)

# %%
r
# Out:
# array([[ 42,  42,  41, ...,  99,  99, 100],
#        [ 42,  42,  42, ..., 100, 101, 102],
#        [ 43,  43,  43, ...,  99,  98,  99],
#        ...,
#        [ 46,  46,  44, ..., 111, 109, 106],
#        [ 47,  48,  44, ..., 132, 121,  99],
#        [ 47,  49,  45, ..., 137, 134, 106]], dtype=uint8)

# %%
# 合成各个颜色
img = cv2.merge((b, g, r))
img.shape
# Out:
# (301, 320, 3)

# %%
cur_img = img.copy()
cur_img[:, :, 0] = 0
cur_img[:, :, 1] = 0
cv_show('cur_img', cur_img)

# %% [markdown]
# ### 边界填充

# %%
top_size, bottom_size, left_size, right_size =  (50, 50, 50, 50)

replicate = cv2.copyMakeBorder(img, top_size, bottom_size, left_size, right_size, borderType=cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img, top_size, bottom_size, left_size, right_size, borderType=cv2.BORDER_REFLECT)
reflect101 = cv2.copyMakeBorder(img, top_size, bottom_size, left_size, right_size, borderType=cv2.BORDER_REFLECT_101)
wrap =  cv2.copyMakeBorder(img, top_size, bottom_size, left_size, right_size, borderType=cv2.BORDER_WRAP)
constant = cv2.copyMakeBorder(img, top_size, bottom_size, left_size, right_size, borderType=cv2.BORDER_CONSTANT, value=0)

# %%
plt.subplot(231), plt.imshow(img, 'gray'), plt.title('ORIGINAL')
plt.subplot(232), plt.imshow(replicate, 'gray'), plt.title('REPLICATE')
plt.subplot(233), plt.imshow(reflect, 'gray'), plt.title('REFLECT')
plt.subplot(234), plt.imshow(reflect101, 'gray'), plt.title('REFLECT101')
plt.subplot(235), plt.imshow(wrap, 'gray'), plt.title('WRAP')
plt.subplot(236), plt.imshow(constant, 'gray'), plt.title('CONSTANT')

plt.show()
